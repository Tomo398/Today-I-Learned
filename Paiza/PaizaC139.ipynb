# %%
# N
# x_1
# x_2
# ...
# x_N

#     ・1 行目に必要な製品番号の範囲を表す整数 N が与えられます。
#     ・続く N 行の i 行目 (1 ≦ i ≦ N) には、i 番目に届いた製品の製品番号が与えられます。
#     ・入力は合計で N + 1 行からなり、入力値最終行の末尾に改行が 1 つ入ります。

import re
N = int(input())
# X = input().split()
# X = list(map(int,input().split()))


data = []
for h in range(N):
    row = int(input())
    data.append(row)

# print(data)
# count = None
# for i in range(N):
#     i = str(i)
#     tempo = re.search(r"\d+",i)
#     if tempo == None:
#         count += 1
#     else:
#         continue

# print(count)

# count = 0
# # for i in range(1,N+1):
# for i in range(1,N+1):
#     i = str(i)
#     check = i in X
#     if check == False:
#         count = count + 1
#     else :
#         continue
    
# print(count)
count = 0
for i in range(1,N+1):
    if i in data:
        pass
    else:
        count = count + 1
print(count)
