# %%
#C157
N = int(input())
A = sorted(input().split())

kinds_count = 1
while_count = len(A)-1
i = 0
while i< while_count:
    if A[i] == A[i+1]:
        pass
    else:
        kinds_count += 1
    i += 1

print(kinds_count)

# %%
#chapの答え
N = int(input())
A = input().split()
print(len(set(A)))
# Out:
# 1
